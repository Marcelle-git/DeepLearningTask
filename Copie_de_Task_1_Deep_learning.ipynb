# %% [markdown]
# <a href="https://colab.research.google.com/github/Marcelle-git/DeepLearningTask/blob/main/Copie_de_Task_1_Deep_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/DataTask1Deeplearning.csv')

# %%
data.head()
#data.info()
# Out:
#     Source        Date    Mean
# 0     GCAG  2016-12-06  0.7895
# 1  GISTEMP  2016-12-06  0.8100
# 2     GCAG  2016-11-06  0.7504
# 3  GISTEMP  2016-11-06  0.9300
# 4     GCAG  2016-10-06  0.7292

# %% [markdown]
# DATA CLEANING

# %%
null_count = data.isnull().sum().sum()        #checking missing values
print('Number of null values:', null_count)
# Out:
# Number of null values: 0

# %%
data['Date'] = pd.to_datetime(data['Date'])
date= data['Date']  #converting data types
data = data.set_index('Date')                  # Applying the set_index method
print(data)
# Out:
#              Source    Mean
# Date
# 2016-12-06     GCAG  0.7895
# 2016-12-06  GISTEMP  0.8100
# 2016-11-06     GCAG  0.7504
# 2016-11-06  GISTEMP  0.9300
# 2016-10-06     GCAG  0.7292
# ...             ...     ...
# 1880-03-06  GISTEMP -0.1800
# 1880-02-06     GCAG -0.1229
# 1880-02-06  GISTEMP -0.2100
# 1880-01-06     GCAG  0.0009
# 1880-01-06  GISTEMP -0.3000
#
# [3288 rows x 2 columns]

# %%
data.drop(columns=['Source'])    #dropping unnecessary columns
# Out:
#               Mean
# Date
# 2016-12-06  0.7895
# 2016-12-06  0.8100
# 2016-11-06  0.7504
# 2016-11-06  0.9300
# 2016-10-06  0.7292
# ...            ...
# 1880-03-06 -0.1800
# 1880-02-06 -0.1229
# 1880-02-06 -0.2100
# 1880-01-06  0.0009
# 1880-01-06 -0.3000
#
# [3288 rows x 1 columns]

# %%
data[['Mean']].resample('M').sum()
# Out:
#               Mean
# Date
# 1880-01-31 -0.2991
# 1880-02-29 -0.3329
# 1880-03-31 -0.3157
# 1880-04-30 -0.3199
# 1880-05-31 -0.2138
# ...            ...
# 2016-08-31  1.8798
# 2016-09-30  1.7467
# 2016-10-31  1.6192
# 2016-11-30  1.6804
# 2016-12-31  1.5995
#
# [1644 rows x 1 columns]

# %%
data.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
results=seasonal_decompose(data['Mean'], period=12)

results.plot()

# %% [markdown]
# Data preparation and feature engineering

# %%
import numpy as np

# %%
from sklearn.preprocessing import MinMaxScaler

def create_sliding_window(data, sequence_length, stride=1):
    X_list, y_list = [], []
    for i in range(len(data)):
      if (i + sequence_length) < len(data):
        X_list.append(data.iloc[i:i+sequence_length:stride, :].values)
        y_list.append(data.iloc[i+sequence_length, -1])
    return np.array(X_list), np.array(y_list)

train_split = 0.7
n_train = int(train_split * len(data))
n_test = len(data) - n_train

features = ['Mean']
feature_array = data[features].values

# Fit Scaler only on Training features
feature_scaler = MinMaxScaler()
feature_scaler.fit(feature_array[:n_train])
# Fit Scaler only on Training target values
target_scaler = MinMaxScaler()
target_scaler.fit(feature_array[:n_train, -1].reshape(-1, 1))

# Transfom on both Training and Test data
scaled_array = pd.DataFrame(feature_scaler.transform(feature_array),
                            columns=features)

sequence_length = 10
X, y = create_sliding_window(scaled_array,
                             sequence_length)
#We are going now to split data into train and test data
X_train = X[:n_train]
y_train = y[:n_train]

X_test = X[n_train:]
y_test = y[n_train:]

# %%
# reshape input to be 3D [samples, timesteps, features]
X_train= X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# We reshaped the input into the 3D format as expected by LSTMs, namely [samples, timesteps, features].
# Out:
# (2301, 1, 10) (2301,) (977, 1, 10) (977,)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.layers import Dropout

# %%
model = Sequential()
model.add(LSTM(100, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
#    model.add(LSTM(70))
#    model.add(Dropout(0.3))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
from sklearn import metrics # for the check the error and accuracy of the model
from sklearn.metrics import mean_squared_error

# %%
# fit network
history = model.fit(X_train, y_train, epochs=70, batch_size=50, validation_data=(X_test, y_test), verbose=2, shuffle=False)

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()


# make a prediction
y_test_predict = model.predict(X_test)
X_test = X_test.reshape((X_test.shape[0], 10))
# invert scaling for forecast
inv_y_test_predict = feature_scaler.inverse_transform(np.concatenate((y_test_predict, X_test[:, -6:]), axis=1))
inv_y_test_predict = inv_y_test_predict[:,0]
# invert scaling for actual
y_test= y_test.reshape((len(y_test), 1))
inv_y = feature_scaler.inverse_transform(np.concatenate((y_test, X_test[:, -6:]), axis=1))
inv_y = inv_y[:,0]
# calculate RMSE
rmse = np.sqrt(mean_squared_error(inv_y, inv_y_test_predict))
print('Test RMSE: %.3f' % rmse)
# Out:
# Epoch 1/70
# 47/47 - 3s - loss: 0.0591 - val_loss: 0.0061 - 3s/epoch - 58ms/step
# Epoch 2/70
# 47/47 - 0s - loss: 0.0038 - val_loss: 0.0035 - 212ms/epoch - 5ms/step
# Epoch 3/70
# 47/47 - 0s - loss: 0.0045 - val_loss: 0.0032 - 254ms/epoch - 5ms/step
# Epoch 4/70
# 47/47 - 0s - loss: 0.0042 - val_loss: 0.0030 - 244ms/epoch - 5ms/step
# Epoch 5/70
# 47/47 - 0s - loss: 0.0039 - val_loss: 0.0030 - 249ms/epoch - 5ms/step
# Epoch 6/70
# 47/47 - 0s - loss: 0.0036 - val_loss: 0.0029 - 235ms/epoch - 5ms/step
# Epoch 7/70
# 47/47 - 0s - loss: 0.0035 - val_loss: 0.0029 - 219ms/epoch - 5ms/step
# Epoch 8/70
# 47/47 - 0s - loss: 0.0035 - val_loss: 0.0029 - 225ms/epoch - 5ms/step
# Epoch 9/70
# 47/47 - 0s - loss: 0.0035 - val_loss: 0.0029 - 256ms/epoch - 5ms/step
# Epoch 10/70
# 47/47 - 0s - loss: 0.0034 - val_loss: 0.0029 - 277ms/epoch - 6ms/step
# Epoch 11/70
# 47/47 - 0s - loss: 0.0033 - val_loss: 0.0028 - 451ms/epoch - 10ms/step
# Epoch 12/70
# 47/47 - 0s - loss: 0.0033 - val_loss: 0.0028 - 355ms/epoch - 8ms/step
# Epoch 13/70
# 47/47 - 0s - loss: 0.0031 - val_loss: 0.0028 - 340ms/epoch - 7ms/step
# Epoch 14/70
# 47/47 - 0s - loss: 0.0031 - val_loss: 0.0028 - 354ms/epoch - 8ms/step
# Epoch 15/70
# 47/47 - 0s - loss: 0.0030 - val_loss: 0.0027 - 340ms/epoch - 7ms/step
# Epoch 16/70
# 47/47 - 0s - loss: 0.0031 - val_loss: 0.0027 - 331ms/epoch - 7ms/step
# Epoch 17/70
# 47/47 - 0s - loss: 0.0031 - val_loss: 0.0028 - 367ms/epoch - 8ms/step
# Epoch 18/70
# 47/47 - 0s - loss: 0.0030 - val_loss: 0.0028 - 362ms/epoch - 8ms/step
# Epoch 19/70
# 47/47 - 0s - loss: 0.0030 - val_loss: 0.0027 - 344ms/epoch - 7ms/step
# Epoch 20/70
# 47/47 - 0s - loss: 0.0029 - val_loss: 0.0027 - 271ms/epoch - 6ms/step
# Epoch 21/70
# 47/47 - 0s - loss: 0.0029 - val_loss: 0.0027 - 252ms/epoch - 5ms/step
# Epoch 22/70
# 47/47 - 0s - loss: 0.0028 - val_loss: 0.0026 - 238ms/epoch - 5ms/step
# Epoch 23/70
# 47/47 - 0s - loss: 0.0028 - val_loss: 0.0026 - 264ms/epoch - 6ms/step
# Epoch 24/70
# 47/47 - 0s - loss: 0.0028 - val_loss: 0.0026 - 249ms/epoch - 5ms/step
# Epoch 25/70
# 47/47 - 0s - loss: 0.0028 - val_loss: 0.0026 - 248ms/epoch - 5ms/step
# Epoch 26/70
# 47/47 - 0s - loss: 0.0028 - val_loss: 0.0025 - 222ms/epoch - 5ms/step
# Epoch 27/70
# 47/47 - 0s - loss: 0.0028 - val_loss: 0.0025 - 251ms/epoch - 5ms/step
# Epoch 28/70
# 47/47 - 0s - loss: 0.0027 - val_loss: 0.0025 - 273ms/epoch - 6ms/step
# Epoch 29/70
# 47/47 - 0s - loss: 0.0027 - val_loss: 0.0025 - 253ms/epoch - 5ms/step
# Epoch 30/70
# 47/47 - 0s - loss: 0.0026 - val_loss: 0.0025 - 248ms/epoch - 5ms/step
# Epoch 31/70
# 47/47 - 0s - loss: 0.0026 - val_loss: 0.0025 - 231ms/epoch - 5ms/step
# Epoch 32/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0025 - 231ms/epoch - 5ms/step
# Epoch 33/70
# 47/47 - 0s - loss: 0.0026 - val_loss: 0.0024 - 205ms/epoch - 4ms/step
# Epoch 34/70
# 47/47 - 0s - loss: 0.0026 - val_loss: 0.0024 - 209ms/epoch - 4ms/step
# Epoch 35/70
# 47/47 - 0s - loss: 0.0027 - val_loss: 0.0025 - 211ms/epoch - 4ms/step
# Epoch 36/70
# 47/47 - 0s - loss: 0.0026 - val_loss: 0.0024 - 237ms/epoch - 5ms/step
# Epoch 37/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0024 - 239ms/epoch - 5ms/step
# Epoch 38/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0024 - 239ms/epoch - 5ms/step
# Epoch 39/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0024 - 220ms/epoch - 5ms/step
# Epoch 40/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0024 - 217ms/epoch - 5ms/step
# Epoch 41/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0024 - 252ms/epoch - 5ms/step
# Epoch 42/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0024 - 240ms/epoch - 5ms/step
# Epoch 43/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0024 - 218ms/epoch - 5ms/step
# Epoch 44/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0024 - 235ms/epoch - 5ms/step
# Epoch 45/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0024 - 242ms/epoch - 5ms/step
# Epoch 46/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0024 - 246ms/epoch - 5ms/step
# Epoch 47/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 217ms/epoch - 5ms/step
# Epoch 48/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0024 - 245ms/epoch - 5ms/step
# Epoch 49/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 254ms/epoch - 5ms/step
# Epoch 50/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 220ms/epoch - 5ms/step
# Epoch 51/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 245ms/epoch - 5ms/step
# Epoch 52/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 238ms/epoch - 5ms/step
# Epoch 53/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 237ms/epoch - 5ms/step
# Epoch 54/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 234ms/epoch - 5ms/step
# Epoch 55/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 245ms/epoch - 5ms/step
# Epoch 56/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 247ms/epoch - 5ms/step
# Epoch 57/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 257ms/epoch - 5ms/step
# Epoch 58/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0023 - 225ms/epoch - 5ms/step
# Epoch 59/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 209ms/epoch - 4ms/step
# Epoch 60/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 226ms/epoch - 5ms/step
# Epoch 61/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 355ms/epoch - 8ms/step
# Epoch 62/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 337ms/epoch - 7ms/step
# Epoch 63/70
# 47/47 - 0s - loss: 0.0023 - val_loss: 0.0023 - 312ms/epoch - 7ms/step
# Epoch 64/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 346ms/epoch - 7ms/step
# Epoch 65/70
# 47/47 - 0s - loss: 0.0023 - val_loss: 0.0023 - 360ms/epoch - 8ms/step
# Epoch 66/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 361ms/epoch - 8ms/step
# Epoch 67/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 330ms/epoch - 7ms/step
# Epoch 68/70
# 47/47 - 0s - loss: 0.0023 - val_loss: 0.0023 - 360ms/epoch - 8ms/step
# Epoch 69/70
# 47/47 - 0s - loss: 0.0024 - val_loss: 0.0023 - 365ms/epoch - 8ms/step
# Epoch 70/70
# 47/47 - 0s - loss: 0.0025 - val_loss: 0.0023 - 343ms/epoch - 7ms/step
# 31/31 [==============================] - 0s 2ms/step
# Test RMSE: 0.094
